# %%
import pygame
import gym
import time

# 初始化环境和Pygame
env = gym.make('SpaceInvaders-v0', render_mode='human')
observation = env.reset()
done = False

pygame.init()
screen = pygame.display.set_mode((400, 300))
pygame.display.set_caption("Space Invaders Control")

# 控制参数
clock = pygame.time.Clock()
move_delay = 0.1  # 按键响应延迟（秒）
last_move_time = 0

while not done:
    current_time = time.time()
    
    # 处理事件（如关闭窗口）
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True

    # 获取按键状态
    keys = pygame.key.get_pressed()
    action = 0  # 默认不动
    
    # 限制按键响应频率
    if current_time - last_move_time > move_delay:
        if keys[pygame.K_RIGHT]:
            action = 2  # 右移
        elif keys[pygame.K_LEFT]:
            action = 3  # 左移
        if keys[pygame.K_SPACE]:
            action = 1  # 开火
        last_move_time = current_time  # 更新最后操作时间

    # 执行动作
    observation, reward, done, _, _ = env.step(action)
    
    # 更新显示
    pygame.display.flip()
    clock.tick(30)  # 限制帧率（约30 FPS）

env.close()
pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.8.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# D:\anaconda\envs\pytorch\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SpaceInvaders-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# D:\anaconda\envs\pytorch\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
